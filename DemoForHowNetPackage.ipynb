# %% [markdown]
# # A simple demo for the HowNet Python Package

# %% [markdown]
# To begin with, make sure you have installed **Python 3.X**.  The **anytree** dependency is required to be installed.
#
# It is our only required dependency because other python packages we need in building the **HowNet** Python Package will be **defaultly** installed with the Python 3.X.
#
# Then you should download the **HowNet** Package.  Please checkout the installation by import the **Standards** module like the following code:

# %%
from HowNet import Standards

# %% [markdown]
# After that we can build a **HowNet dict**:

# %%
hownet_dict = Standards.HowNetDict()

# %% [markdown]
# Finally, the preparation work is all done! Then let's explore some important features of HowNetDict!

# %% [markdown]
# # Basic Usage of OpenHowNet Python Package

# %% [markdown]
# ## Get word annotations in HowNet
# <b> By default, the api will search the target word in both English and Chinese annotations in HowNet, which will cause significant search overhead. Note that if the target word does not exist in HowNet annotation, this api will simply return an empty list. </b>

# %%
result_list = hownet_dict.get("苹果")
print("检索数量：",len(result_list))
print("检索结果范例:",result_list[0])
# Out:
# 检索数量： 6
# 检索结果范例: {'Def': '{computer|电脑:modifier={PatternValue|样式值:CoEvent={able|能:scope={bring|携带:patient={$}}}}{SpeBrand|特定牌子}}', 'en_grammar': 'noun', 'ch_grammar': 'noun', 'No': '127151', 'syn': [{'id': '004024', 'text': 'IBM'}, {'id': '041684', 'text': '戴尔'}, {'id': '049006', 'text': '东芝'}, {'id': '106795', 'text': '联想'}, {'id': '156029', 'text': '索尼'}, {'id': '004203', 'text': 'iPad'}, {'id': '019457', 'text': '笔记本'}, {'id': '019458', 'text': '笔记本电脑'}, {'id': '019459', 'text': '笔记本电脑'}, {'id': '019460', 'text': '笔记本电脑'}, {'id': '019461', 'text': '笔记本电脑'}, {'id': '019463', 'text': '笔记簿电脑'}, {'id': '019464', 'text': '笔记簿电脑'}, {'id': '020567', 'text': '便携式电脑'}, {'id': '020568', 'text': '便携式计算机'}, {'id': '020569', 'text': '便携式计算机'}, {'id': '127224', 'text': '平板电脑'}, {'id': '127225', 'text': '平板电脑'}, {'id': '172264', 'text': '膝上型电脑'}, {'id': '172265', 'text': '膝上型电脑'}], 'ch_word': '苹果', 'en_word': 'apple'}

# %%
hownet_dict.get("test_for_non_exist_word")
# Out:
# []

# %% [markdown]
# <b> You can visualize the retrieved HowNet structured annotations ("sememe tree") of the target word as follow : <br>
#     (K=2 means only display 2 sememe trees) </b>

# %%
hownet_dict.visualize_sememe_trees("苹果", K=2)
# Out:
# Find 6 result(s)
# Display #0 sememe tree
# [None]computer|电脑
# ├── [modifier]PatternValue|样式值
# │   └── [CoEvent]able|能
# │       └── [scope]bring|携带
# │           └── [patient]$
# └── [patient]SpeBrand|特定牌子
# Display #1 sememe tree
# [None]fruit|水果

# %% [markdown]
# <b> To boost the efficiency of the search process, you can specify the language of the target word as the following. </b>

# %%
result_list = hownet_dict.get("苹果", language="ch")
print("单语检索数量：",len(result_list))
print("单语检索结果范例:",result_list[0])
print("-------双语混合检索测试---------")
print("混合检索结果数量:",len(hownet_dict.get("X")))
print("中文检索结果数量:",len(hownet_dict.get("X",language="ch")))
print("英语检索结果数量:",len(hownet_dict.get("X",language="en")))
# Out:
# 单语检索数量： 6
# 单语检索结果范例: {'Def': '{computer|电脑:modifier={PatternValue|样式值:CoEvent={able|能:scope={bring|携带:patient={$}}}}{SpeBrand|特定牌子}}', 'en_grammar': 'noun', 'ch_grammar': 'noun', 'No': '127151', 'syn': [{'id': '004024', 'text': 'IBM'}, {'id': '041684', 'text': '戴尔'}, {'id': '049006', 'text': '东芝'}, {'id': '106795', 'text': '联想'}, {'id': '156029', 'text': '索尼'}, {'id': '004203', 'text': 'iPad'}, {'id': '019457', 'text': '笔记本'}, {'id': '019458', 'text': '笔记本电脑'}, {'id': '019459', 'text': '笔记本电脑'}, {'id': '019460', 'text': '笔记本电脑'}, {'id': '019461', 'text': '笔记本电脑'}, {'id': '019463', 'text': '笔记簿电脑'}, {'id': '019464', 'text': '笔记簿电脑'}, {'id': '020567', 'text': '便携式电脑'}, {'id': '020568', 'text': '便携式计算机'}, {'id': '020569', 'text': '便携式计算机'}, {'id': '127224', 'text': '平板电脑'}, {'id': '127225', 'text': '平板电脑'}, {'id': '172264', 'text': '膝上型电脑'}, {'id': '172265', 'text': '膝上型电脑'}], 'ch_word': '苹果', 'en_word': 'apple'}
# -------双语混合检索测试---------
# 混合检索结果数量: 5
# 中文检索结果数量: 3
# 英语检索结果数量: 2

# %%
hownet_dict.get("苹果", language="en")
# Out:
# []

# %% [markdown]
# ## Get All Words annotated in HowNet

# %%
ch_word_list = hownet_dict.get_ch_words()
en_word_list = hownet_dict.get_en_words()

# %%
print(ch_word_list[:30])
# Out:
# ['', '"', '#', '#号标签', '$', '%', "'", '(', ')', '*', '+', '-', '--', '...', '...出什么问题', '...底', '...底下', '...发生故障', '...发生了什么', '...何如', '...家里有几口人', '...检测呈阳性', '...检测呈阴性', '...来', '...内', '...为止', '...也同样使然', '...以来', '...以内', '...以上']

# %%
print(en_word_list[:30])
# Out:
# ['A', 'An', 'Frenchmen', 'Frenchwomen', 'Ottomans', 'a', 'aardwolves', 'abaci', 'abandoned', 'abbreviated', 'abode', 'aboideaux', 'aboiteaux', 'abscissae', 'absorbed', 'acanthi', 'acari', 'accepted', 'acciaccature', 'acclaimed', 'accommodating', 'accompanied', 'accounting', 'accused', 'acetabula', 'acetified', 'aching', 'acicula', 'acini', 'acquired']

# %% [markdown]
# ## Get Flattened Sememe Trees for certain word or all words in HowNet
#
# <b> Cautions: the parameters "lang", "merge" and "expanded_layer" only works when "structured = False". The main consideration is that there are multiple ways to interpret these params when deal with structured data. We leave the freedom to our end user. In next section, you will be able to see how to utilize the structured data.
#
#    Detailed explanation of params will be displayed in our documentation.</b>

# %% [markdown]
# ### Get the full merged sememe list from multi-sense words

# %%
hownet_dict.get_sememes_by_word("苹果",structured=False,lang="ch",merge=True)
# Out:
# {'交流', '携带', '树', '样式值', '水果', '特定牌子', '生殖', '用具', '电脑', '能'}

# %%
hownet_dict.get_sememes_by_word("apple",structured=False,lang="en",merge=True)
# Out:
# {'$',
#  'PatternValue',
#  'SpeBrand',
#  'able',
#  'bring',
#  'communicate',
#  'computer',
#  'fruit',
#  'reproduce',
#  'tool',
#  'tree'}

# %% [markdown]
# **Even if the language is not corresponding to the target word, the api still works. It will keep all the returned word entries to be in the same language you specified**

# %%
hownet_dict.get_sememes_by_word("苹果",structured=False,lang="en",merge=True)
# Out:
# {'apple': {'$',
#   'PatternValue',
#   'SpeBrand',
#   'able',
#   'bring',
#   'communicate',
#   'computer',
#   'fruit',
#   'reproduce',
#   'tool',
#   'tree'},
#  'malus pumila': {'fruit', 'reproduce', 'tree'},
#  'orchard apple tree': {'fruit', 'reproduce', 'tree'}}

# %% [markdown]
# **Note that, in the latest version, if the number of the word entries equals to one, for convenience, the api will simply return the set of sememes. See Out[11] for example.**

# %% [markdown]
# <b> You could specify the number of the expanded layers like the following:</b>

# %%
hownet_dict.get_sememes_by_word("苹果",structured=False,merge=True,expanded_layer=1)
# Out:
# {'树', '水果', '用具', '电脑'}

# %% [markdown]
# <b>You could get all flattened sememe trees for all words as well as specify the number of the expanded layers:</b>

# %%
hownet_dict.get_sememes_by_word("*",structured=False,merge=True)
# Out:
# {'': {'上',
#   '他',
#   '你',
#   '内',
#   '再',
#   '功能词',
#   '动趋',
#   '否',
#   '复',
#   '外',
#   '它',
#   '尾',
#   '我',
#   '来',
#   '构助',
#   '特定',
#   '特性值',
#   '疑问',
#   '词语',
#   '超',
#   '较',
#   '部件',
#   '非'},
#  '"': {'标点'},
#  '#': {'符号', '语文'},
#  '#号标签': {'标志'},
#  '$': {'单位', '商业', '美国', '货币', '金融'},
#  '%': {'基数', '数学', '比率'},
#  "'": {'标点'},
#  '(': {'标点'},
#  ')': {'标点'},
#  '*': {'标点'},
#  '+': {'增加', '符号', '算术'},
#  '-': {'削减', '标点', '符号', '算术'},
#  '--': {'标点'},
#  '...': {'标点'},
#  '...出什么问题': {'坏掉'},
#  '...底': {'功能词'},
#  '...底下': {'下', '位置'},
#  '...发生故障': {'坏掉'},
#  '...发生了什么': {'发生'},
#  '...何如': {'念头', '表示', '词语', '谋取'},
#  '...家里有几口人': {'表示', '词语', '问'},
#  '...检测呈阳性': {'医', '是', '正面', '疾病'},
#  '...检测呈阴性': {'医', '反面', '是', '疾病'},
#  '...来': {'功能词', '动趋', '去'},
#  '...内': {'内', '功能词', '动趋'},
#  '...为止': {'功能词'},
#  '...也同样使然': {'相像'},
#  '...以来': {'功能词'},
#  '...以内': {'功能词'},
#  '...以上': {'功能词'},
#  '...怎么样': {'念头', '表示', '词语', '谋取'},
#  '...止': {'功能词'},
#  '.22口径': {'粗细值'},
#  '.38口径': {'粗细值'},
#  '.45口径': {'粗细值'},
#  '/': {'削减', '标点', '符号', '算术'},
#  '//': {'标点'},
#  '0': {'基数'},
#  '00万': {'基数'},
#  '01': {'基数'},
#  '02': {'基数'},
#  '03': {'基数'},
#  '04': {'基数'},
#  '05': {'基数'},
#  '06': {'基数'},
#  '07': {'基数'},
#  '08': {'基数'},
#  '09': {'基数'},
#  '0级风': {'风'},
#  '1': {'基数'},
#  '1%': {'基数'},
#  '1/10': {'基数'},
#  '1/3': {'基数'},
#  '1/4': {'基数'},
#  '1/5': {'基数'},
#  '1/6': {'基数'},
#  '1/7': {'基数'},
#  '1/8': {'基数'},
#  '1/9': {'基数'},
#  '10': {'基数'},
#  '10%': {'基数'},
#  '100': {'基数'},
#  '1000': {'基数'},
#  '10000': {'基数'},
#  '1000吉字节': {'信息', '单位', '电脑'},
#  '1000周年': {'日', '时间', '特定', '祝贺', '节'},
#  '1001': {'基数'},
#  '100克': {'单位', '重量'},
#  '101': {'基数'},
#  '102': {'基数'},
#  '103': {'基数'},
#  '104': {'基数'},
#  '105': {'基数'},
#  '106': {'基数'},
#  '107': {'基数'},
#  '108': {'基数'},
#  '109': {'基数'},
#  '10点': {'时', '时间', '特定'},
#  '10分': {'商业', '美国', '货币', '金融'},
#  '10克': {'单位', '重量'},
#  '10米': {'单位', '宽度', '距离', '长度'},
#  '10米气步枪': {'事情', '体育', '锻炼'},
#  '10米气手枪': {'事情', '体育', '锻炼'},
#  '10年': {'多', '年', '时间'},
#  '10年级': {'人', '场所', '学习', '教', '教育', '等级'},
#  '10万': {'基数'},
#  '10亿': {'基数'},
#  '10月': {'时间', '月', '特定'},
#  '10月初': {'始', '时间', '月', '特定'},
#  '10月底': {'时间', '月', '末', '特定'},
#  '10月份': {'时间', '月', '特定'},
#  '10月末': {'时间', '月', '末', '特定'},
#  '11': {'基数'},
#  '110': {'基数'},
#  '111': {'基数'},
#  '112': {'基数'},
#  '113': {'基数'},
#  '114': {'基数'},
#  '115': {'基数'},
#  '11点': {'时', '时间', '特定'},
#  '11年级': {'人', '场所', '学习', '教', '教育', '等级'},
#  '11月': {'时间', '月', '特定'},
#  '11月初': {'始', '时间', '月', '特定'},
#  '11月底': {'时间', '月', '末', '特定'},
#  '11月份': {'时间', '月', '特定'},
#  '11月末': {'时间', '月', '末', '特定'},
#  '12': {'基数'},
#  '12点': {'时', '时间', '特定'},
#  '12海里': {'单位', '宽度', '水域', '船', '距离', '长度'},
#  '12年级': {'人', '场所', '学习', '教', '教育', '等级'},
#  '12星座': {'人', '类型', '问世'},
#  '12月': {'时间', '月', '特定'},
#  '12月初': {'始', '时间', '月', '特定'},
#  '12月底': {'时间', '月', '末', '特定'},
#  '12月份': {'时间', '月', '特定'},
#  '12月末': {'时间', '月', '末', '特定'},
#  '13': {'基数'},
#  '14': {'基数'},
#  '15': {'基数'},
#  '150周年': {'日', '时间', '祝贺', '节'},
#  '15世纪': {'时间', '特定', '现在'},
#  '16': {'基数'},
#  '16世纪': {'时间', '现在'},
#  '16世纪70年代': {'时间', '特定'},
#  '17': {'基数'},
#  '17世纪': {'时间', '现在'},
#  '18': {'基数'},
#  '18开金': {'化学', '金属'},
#  '18楼5单元3510号': {'专', '居民区', '房屋'},
#  '18世纪': {'时间', '现在'},
#  '19': {'基数'},
#  '1936年12月12日': {'年', '日', '时间', '月', '特定'},
#  '1963大示威': {'专', '事情', '政', '美国'},
#  '19世纪': {'时间', '现在'},
#  '1点': {'时', '时间', '特定'},
#  '1级风': {'风'},
#  '1年级': {'人', '场所', '学习', '教', '教育', '等级'},
#  '1频道': {'传播', '设施'},
#  '1月': {'时间', '月', '特定'},
#  '1月初': {'始', '时间', '月', '特定'},
#  '1月底': {'时间', '月', '末', '特定'},
#  '1月份': {'时间', '月', '特定'},
#  '1月末': {'时间', '月', '末', '特定'},
#  '2': {'基数'},
#  '2.0级': {'劫难', '地方', '强度', '陆地', '颤动'},
#  '20': {'基数'},
#  '20%': {'基数'},
#  '200': {'基数'},
#  '2000': {'基数'},
#  '2000周年': {'时间'},
#  '200周年': {'日', '时间', '祝贺', '节'},
#  '20多岁到30刚出头': {'年龄值', '青年'},
#  '20国': {'众', '国家', '地方', '政'},
#  '20年': {'多', '年', '时间'},
#  '20年代': {'时间', '特定'},
#  '20世纪': {'时间', '现在'},
#  '20世纪福克斯': {'专', '制造', '场所', '拍摄', '美国', '艺', '表演物'},
#  '21': {'基数'},
#  '21世纪': {'时间', '现在'},
#  '21响礼炮': {'用具', '致敬'},
#  '22': {'基数'},
#  '22开金': {'化学', '金属'},
#  '23': {'基数'},
#  '24': {'基数'},
#  '24开金': {'化学', '金属'},
#  '25': {'基数'},
#  '25%': {'基数'},
#  '26': {'基数'},
#  '27': {'基数'},
#  '28': {'基数'},
#  '29': {'基数'},
#  '2点': {'时', '时间', '特定'},
#  '2级风': {'风'},
#  '2年级': {'人', '场所', '学习', '教', '教育', '等级'},
#  '2频道': {'传播', '设施'},
#  '2月': {'时间', '月', '特定'},
#  '2月14日': {'日', '时间', '特定'},
#  '2月初': {'始', '时间', '月', '特定'},
#  '2月底': {'时间', '月', '末', '特定'},
#  '2月份': {'时间', '月', '特定'},
#  '2月末': {'时间', '月', '末', '特定'},
#  '3': {'基数'},
#  '30': {'基数'},
#  '300': {'基数'},
#  '3000米障碍赛': {'事情', '体育', '锻炼'},
#  '300周年': {'日', '时间', '祝贺', '节'},
#  '30多岁到40刚出头': {'年龄值', '青年'},
#  '30年': {'多', '年', '时间'},
#  '30年代': {'时间', '特定'},
#  '31': {'基数'},
#  '32': {'基数'},
#  '33': {'基数'},
#  '34': {'基数'},
#  '35': {'基数'},
#  '36': {'基数'},
#  '365天': {'单位', '日', '时间'},
#  '366天': {'单位', '日', '时间'},
#  '37': {'基数'},
#  '38': {'基数'},
#  '39': {'基数'},
#  '3D打印': {'事情', '印刷'},
#  '3点': {'时', '时间', '特定'},
#  '3级风': {'弱', '风'},
#  '3年级': {'人', '场所', '学习', '教', '教育', '等级'},
#  '3月': {'时间', '月', '特定'},
#  '3月初': {'始', '时间', '月', '特定'},
#  '3月底': {'时间', '月', '末', '特定'},
#  '3月份': {'时间', '月', '特定'},
#  '3月末': {'时间', '月', '末', '特定'},
#  '4': {'基数'},
#  '40': {'基数'},
#  '400': {'基数'},
#  '400周年': {'日', '时间', '祝贺', '节'},
#  '40多岁到50刚出头': {'中年', '年龄值'},
#  '40年': {'多', '年', '时间'},
#  '40年代': {'时间', '特定'},
#  '41': {'基数'},
#  '42': {'基数'},
#  '43': {'基数'},
#  '44': {'基数'},
#  '45': {'基数'},
#  '45手枪': {'军', '射击', '武器'},
#  '46': {'基数'},
#  '47': {'基数'},
#  '48': {'基数'},
#  '49': {'基数'},
#  '4点': {'时', '时间', '特定'},
#  '4级风': {'弱', '风'},
#  '4月': {'时间', '月', '特定'},
#  '4月初': {'始', '时间', '月', '特定'},
#  '4月底': {'时间', '月', '末', '特定'},
#  '4月份': {'时间', '月', '特定'},
#  '4月末': {'时间', '月', '末', '特定'},
#  '5': {'基数'},
#  '5.5级': {'劫难', '地方', '强度', '陆地', '颤动'},
#  '50': {'基数'},
#  '50%': {'半'},
#  '500': {'基数'},
#  '5000': {'基数'},
#  '500周年': {'日', '时间', '祝贺', '节'},
#  '50多岁到60刚出头': {'中年', '年龄值'},
#  '50米步枪3种姿势': {'事情', '体育', '锻炼'},
#  '50年': {'多', '年', '时间'},
#  '50年代': {'时间', '特定'},
#  '50周年': {'日', '时间', '祝贺', '节'},
#  '51': {'基数'},
#  '52': {'基数'},
#  '53': {'基数'},
#  '54': {'基数'},
#  '55': {'基数'},
#  '56': {'基数'},
#  '57': {'基数'},
#  '58': {'基数'},
#  '59': {'基数'},
#  '5点': {'时', '时间', '特定'},
#  '5级风': {'风'},
#  '5年级': {'人', '场所', '学习', '教', '教育', '等级'},
#  '5月': {'时间', '月', '特定'},
#  '5月初': {'始', '时间', '月', '特定'},
#  '5月底': {'时间', '月', '末', '特定'},
#  '5月份': {'时间', '月', '特定'},
#  '5月末': {'时间', '月', '末', '特定'},
#  '6': {'基数'},
#  '6.0级': {'劫难', '地方', '强度', '陆地', '颤动'},
#  '6.5级': {'劫难', '地方', '强度', '陆地', '颤动'},
#  '60': {'基数'},
#  '60大寿': {'日', '时间', '祝贺', '问世'},
#  '60年': {'多', '年', '时间'},
#  '60年代': {'时间', '特定'},
#  '61': {'基数'},
#  '62': {'基数'},
#  '63': {'基数'},
#  '64': {'基数'},
#  '65': {'基数'},
#  '65岁以上': {'老年'},
#  '66': {'基数'},
#  '67': {'基数'},
#  '68': {'基数'},
#  '69': {'基数'},
#  '6点': {'时', '时间', '特定'},
#  '6个P': {'出现', '医', '现象', '疾病'},
#  '6级风': {'坏天', '强', '风'},
#  '6年级': {'人', '场所', '学习', '教', '教育', '等级'},
#  '6月': {'时间', '月', '特定'},
#  '6月初': {'始', '时间', '月', '特定'},
#  '6月底': {'时间', '月', '末', '特定'},
#  '6月份': {'时间', '月', '特定'},
#  '6月末': {'时间', '月', '末', '特定'},
#  '7': {'基数'},
#  '7.0级': {'劫难', '地方', '强度', '陆地', '颤动'},
#  '70': {'基数'},
#  '70年': {'多', '年', '时间'},
#  '70年代': {'时间', '特定'},
#  '71': {'基数'},
#  '72': {'基数'},
#  '73': {'基数'},
#  '74': {'基数'},
#  '75': {'基数'},
#  '76': {'基数'},
#  '77': {'基数'},
#  '78': {'基数'},
#  '79': {'基数'},
#  '7点': {'时', '时间', '特定'},
#  '7年级': {'人', '场所', '学习', '教', '教育', '等级'},
#  '7月': {'时间', '月', '特定'},
#  '7月初': {'始', '时间', '月', '特定'},
#  '7月底': {'时间', '月', '末', '特定'},
#  '7月份': {'时间', '月', '特定'},
#  '7月末': {'时间', '月', '末', '特定'},
#  '8': {'基数'},
#  '8.5级': {'劫难', '地方', '强度', '陆地', '颤动'},
#  '80': {'基数'},
#  '80年': {'多', '年', '时间'},
#  '80年代': {'时间', '特定'},
#  '81': {'基数'},
#  '82': {'基数'},
#  '83': {'基数'},
#  '84': {'基数'},
#  '85': {'基数'},
#  '86': {'基数'},
#  '87': {'基数'},
#  '88': {'基数'},
#  '89': {'基数'},
#  '8点': {'时', '时间', '特定'},
#  '8年级': {'人', '场所', '学习', '教', '教育', '等级'},
#  '8月': {'时间', '月', '特定'},
#  '8月初': {'始', '时间', '月', '特定'},
#  '8月底': {'时间', '月', '末', '特定'},
#  '8月份': {'时间', '月', '特定'},
#  '8月末': {'时间', '月', '末', '特定'},
#  '9': {'基数'},
#  '90': {'基数'},
#  '90年': {'多', '年', '时间'},
#  '90年代': {'时间', '特定'},
#  '91': {'基数'},
#  '911': {'专', '事情', '地方', '恐怖袭击', '美国'},
#  '911报警电话': {'事情', '交流', '用具', '距离值', '长'},
#  '92': {'基数'},
#  '93': {'基数'},
#  '94': {'基数'},
#  '95': {'基数'},
#  '96': {'基数'},
#  '97': {'基数'},
#  '98': {'基数'},
#  '99': {'基数'},
#  '9·11': {'专', '事情', '地方', '恐怖袭击', '美国'},
#  '9点': {'时', '时间', '特定'},
#  '9年级': {'人', '场所', '学习', '教', '教育', '等级'},
#  '9月': {'时间', '月', '特定'},
#  '9月初': {'始', '时间', '月', '特定'},
#  '9月底': {'时间', '月', '末', '特定'},
#  '9月份': {'时间', '月', '特定'},
#  '9月末': {'时间', '月', '末', '特定'},
#  '<': {'标点'},
#  '=': {'标点'},
#  '>': {'标点'},
#  '@': {'符号', '语文'},
#  'A': {'文字', '英国'},
#  'ACL': {'事情', '商讨', '集聚'},
#  'AK-47': {'军', '射击', '武器'},
#  'AK-47步枪': {'军', '射击', '武器'},
#  'ALGOL': {'编辑', '语言', '软件'},
#  'APC': {'药物'},
#  'ASCII': {'电脑', '符号', '软件'},
#  'AT&T': {'专', '人工物', '使动', '制造', '场所', '工', '性能值', '电', '美国'},
#  'AV': {'内容', '包含', '淫', '表演物'},
#  'B': {'文字', '英国'},
#  'B2B': {'事务', '商业', '因特网', '实施'},
#  'B2C': {'事务', '商业', '因特网', '实施'},
#  'BN(O)护照': {'文书', '旅游', '证明'},
#  'Bob': {'专', '人', '姓名'},
#  'Brian': {'人', '姓名'},
#  'Burger': {'吃', '商业', '场所', '特定牌子'},
#  'B超': {'事情', '医', '图像', '形成', '用具', '电脑', '诊察'},
#  'C': {'文字', '英国'},
#  'C3I': {'军', '设施'},
#  'C4I': {'军', '设施'},
#  'CD播放机': {'传播', '用具', '音乐'},
#  'CD随身听': {'听', '携带', '用具', '能', '音乐'},
#  'CES': {'事情', '人工物', '使动', '展示', '性能值', '电'},
#  'CNN': {'专', '传播', '新闻', '机构', '美国', '采集'},
#  'COBOL': {'编辑', '语言', '软件'},
#  'CPI持续走高': {'价值', '价格', '商业', '增多', '金融'},
#  'CPU': {'心', '电脑', '部件'},
#  'CT冠状动脉成像': {'事情', '医', '图像', '形成', '电脑', '诊察'},
#  'CT血管造影': {'事情', '医', '图像', '形成', '电脑', '诊察'},
#  'Costco': {'买', '卖', '商业', '场所', '特定牌子'},
#  'C编译器': {'软件'},
#  'C系列': {'专', '类型', '飞行器'},
#  'D': {'文字', '英国'},
#  'DVD播放机': {'传播', '用具', '音乐'},
#  'E': {'文字', '英国'},
#  'E.': {'文字', '英国'},
#  'EMBA': {'人', '教育', '有', '身分', '较', '高等'},
#  'EMS': {'事情', '快', '邮寄'},
#  'EV71': {'医', '导致', '微生物', '疾病', '能'},
#  'Edward': {'人', '姓名'},
#  'F': {'文字', '英国'},
#  'FBI': {'事务', '官', '归属中央', '政', '机构', '管理', '美国', '警', '部件'},
#  'FaceBook': {'信息载体', '因特网', '文书', '有', '电脑'},
#  'Facebook': {'专', '信息', '制造', '因特网', '场所', '寻', '文书', '软件'},
#  'Fortran编译器': {'软件'},
#  'G': {'文字', '英国'},
#  'Gore': {'人', '姓名'},
#  'Graham': {'人', '姓名'},
#  'G点': {'位置', '动物', '女', '排泄', '生殖', '脏', '部件'},
#  'H': {'文字', '英国'},
#  'H-1B签证': {'国家', '地方', '文书', '进入'},
#  'H1N1': {'医', '导致', '微生物', '疾病', '能'},
#  'H1N1A型流感': {'牲畜', '疾病'},
#  'H5N1': {'医', '导致', '微生物', '疾病', '能'},
#  'H7N9': {'医', '导致', '微生物', '疾病', '能'},
#  'HTN': {'疾病'},
#  'Henry': {'人', '姓名'},
#  'I': {'代谢', '基数', '文字', '疾病', '英国'},
#  'IBM': {'专', '制造', '场所', '工', '携带', '样式值', '特定牌子', '电脑', '美国', '能'},
#  'IELTS': {'事情', '教育', '考试', '英国', '语言'},
#  'II': {'代谢', '基数', '疾病'},
#  'III': {'基数'},
#  'III级': {'中等'},
#  'II级': {'中等'},
#  'IPO': {'买', '事情', '出现', '卖', '场所', '证券'},
#  'IT': {'信息', '知识'},
#  'IV': {'基数'},
#  'IV级': {'中等'},
#  'IX': {'基数'},
#  'IXX': {'基数'},
#  'Instagram': {'信息载体', '因特网', '文书', '有', '电脑'},
#  'I级': {'最佳'},
#  'J': {'文字', '英国'},
#  'Jack': {'人', '姓名'},
#  'James': {'人', '姓名'},
#  'Java': {'编辑', '语言', '软件'},
#  'John': {'人', '姓名'},
#  'Josh': {'人', '姓名'},
#  'Jr.': {'人', '姓名'},
#  'K': {'文字', '英国'},
#  'KAIST': {'专', '场所', '学习', '教', '教育', '韩国', '高等'},
#  'KAIST大学': {'专', '场所', '学习', '教', '教育', '韩国', '高等'},
#  'K粉': {'毒品'},
#  'L': {'文字', '英国'},
#  'LinkedIn': {'信息载体', '因特网', '文书', '有', '电脑'},
#  'Lisp编译器': {'软件'},
#  'Loblaws': {'买', '卖', '商业', '场所', '特定牌子'},
#  'M': {'文字', '英国'},
#  'MD录放机': {'传播', '用具', '音乐'},
#  'MD随身听': {'听', '携带', '用具', '能', '音乐'},
#  'MP3': {'听', '携带', '用具', '能', '音乐'},
#  'MSR': {'场所', '知识', '研究', '美国'},
#  'Mar': {'人', '姓名'},
#  'Martin': {'专', '人'},
#  'MasterCard': {'付', '取回', '文书', '留存', '货币', '金融'},
#  'N': {'文字', '英国'},
#  'NBA': {'专', '体育', '团体', '篮球', '美国'},
#  'NIST': {'官', '归属中央', '政', '机构', '监察', '知识', '管理', '美国', '部件'},
#  'No.': {'指代', '次序', '符号'},
#  'O': {'文字', '英国'},
#  'Omega-3脂肪酸': {'化学物', '生物学'},
#  'Omega-6脂肪酸': {'化学物', '生物学'},
#  'Omega脂肪酸': {'化学物', '生物学'},
#  'One-Alpha': {'药物'},
#  'P': {'文字', '英国'},
#  'PM': {'天象', '气', '物质', '质量'},
#  'PM2.5': {'天象', '气', '物质', '质量'},
#  'PM2.5浓度': {'天象', '气', '浓度', '物理', '物质', '质量'},
#  'PVC保鲜膜': {'保持', '新', '用具'},
#  'Pascal编译器': {'软件'},
#  'Q': {'文字', '英国'},
#  'QQ': {'交流', '信息', '信息载体', '因特网'},
#  'QQ号': {'交流', '信息', '信息载体', '因特网', '指代', '次序', '符号'},
#  'QQ群': {'交流', '信息', '信息载体', '因特网'},
#  'R': {'文字', '英国'},
#  'RBC': {'专', '借入', '加拿大', '取回', '场所', '留存', '货币', '金融'},
#  'Rob': {'人', '姓名'},
#  'S': {'文字', '英国'},
#  'SARS': {'动物', '呼吸', '疾病', '脏', '部件'},
#  'SCO': {'专', '国际', '政', '机构', '规矩'},
#  'SMAC': {'事务', '共', '担任'},
#  'SMS': {'事务', '信息', '卖', '商业', '照料', '短'},
#  'SOHO族': {'事务', '人', '从事', '家庭', '责任'},
#  'Sears': {'专', '买', '加拿大', '卖', '商业', '场所'},
#  'Senkaku岛': {'专', '中国', '水域', '陆地'},
#  'SoLoMo': {'事情', '交往'},
#  'Sr.': {'人', '姓名'},
#  'S形': {'形状值'},
#  'T': {'文字', '英国'},
#  'TNT': {'使动', '坏掉', '形变', '攻打', '材料', '点燃', '用具'},
#  'Target': {'专', '买', '卖', '商业', '场所', '美国'},
#  'Ted': {'专', '人', '姓名'},
#  'Tim': {'商业', '喝', '场所', '特定牌子', '饮品'},
#  'Twitter': {'专', '信息', '制造', '因特网', '场所', '寻', '文书', '软件'},
#  'U': {'文字', '英国'},
#  'UNIX': {'控制', '电脑', '软件'},
#  'UNIX操作系统': {'控制', '电脑', '软件'},
#  'USB闪存盘': {'保存', '电脑', '配件'},
#  'U盘': {'保存', '电脑', '配件'},
#  'U形': {'弯'},
#  'V': {'基数', '文字', '英国'},
#  'VI': {'基数'},
#  'VII': {'基数'},
#  'VIII': {'基数'},
#  'VISA卡': {'付', '取回', '文书', '留存', '货币', '金融'},
#  'VPN': {'信息载体', '因特网', '文书', '有', '电脑'},
#  'VX毒剂': {'化学物', '有毒'},
#  'Via旅客列车': {'人', '加拿大', '材料', '线', '车', '运送', '道路', '金属', '驶'},
#  'W': {'文字', '英国'},
#  'WTO': {'专', '国际', '机构', '经济', '规矩'},
#  'Wi-Fi': {'交流', '传播', '信息', '方法'},
#  'X': {'基数', '增加', '文字', '符号', '算术', '英国'},
#  'XI': {'基数'},
#  'XII': {'基数'},
#  'XIII': {'基数'},
#  'XIV': {'基数'},
#  'XIX': {'基数'},
#  'XO酱': {'味道', '材料', '调整'},
#  'XO辣椒酱': {'味道', '材料', '调整'},
#  'XV': {'基数'},
#  'XVI': {'基数'},
#  'XVII': {'基数'},
#  'XVIII': {'基数'},
#  'XX': {'基数'},
#  'XXI': {'基数'},
#  'XXII': {'基数'},
#  'XXIII': {'基数'},
#  'XXIV': {'基数'},
#  'XXV': {'基数'},
#  'XXVI': {'基数'},
#  'XXX': {'基数'},
#  'XXXI': {'基数'},
#  'XXXII': {'基数'},
#  'XXXIII': {'基数'},
#  'XXXIV': {'基数'},
#  'XXXIX': {'基数'},
#  'XXXVI': {'基数'},
#  'XXXVII': {'基数'},
#  'XXXVIII': {'基数'},
#  'XXXX': {'基数'},
#  'XXXXI': {'基数'},
#  'X光线照相': {'事情', '医', '图像', '形成', '诊察'},
#  'X线断层摄影': {'事情', '医', '图像', '形成', '电脑', '诊察'},
#  'X线断层摄影术': {'事情', '医', '图像', '形成', '电脑', '诊察'},
#  'X线断层摄影装置': {'创造', '器具', '图像'},
#  'X线断层照片': {'图像', '拍摄'},
#  'Y': {'文字', '英国'},
#  'YouTube': {'信息载体', '因特网', '文书', '有', '电脑'},
#  'Y形': {'形状值'},
#  'Z': {'文字', '英国'},
#  '[': {'标点'},
#  '\\': {'标点'},
#  ']': {'标点'},
#  '^': {'符号', '语文'},
#  '_': {'符号', '语文'},
#  '`': {'标点'},
#  'a': {'文字', '英国'},
#  'a.': {'文字', '英国'},
#  'alpha': {'希腊', '文字'},
#  'b': {'文字', '英国'},
#  'beta': {'希腊', '文字'},
#  'c': {'文字', '英国'},
#  'd': {'文字', '英国'},
#  'e': {'文字', '英国'},
#  'email地址': {'交流', '位置', '信件', '因特网'},
#  'f': {'文字', '英国'},
#  'fax': {'图像', '邮寄'},
#  'g': {'文字', '英国'},
#  'h': {'文字', '英国'},
#  'http': {'因特网', '文书', '约定'},
#  'http:': {'因特网', '文书', '约定'},
#  'https:': {'因特网', '文书', '约定'},
#  'i': {'基数', '文字', '英国'},
#  'iPad': {'携带', '样式值', '电脑', '能'},
#  'ii': {'基数'},
#  'iii': {'基数'},
#  'iphone': {'交流', '携带', '样式值', '用具', '能'},
#  'iv': {'基数'},
#  'ix': {'基数'},
#  'j': {'文字', '英国'},
#  'k': {'单位', '文字', '材料', '英国', '重量', '金属'},
#  'l': {'文字', '英国'},
#  'm': {'文字', '英国'},
#  'n': {'文字', '英国'},
#  'o': {'文字', '英国'},
#  'omega': {'希腊', '文字'},
#  'omega-3脂肪酸': {'化学物', '生物学'},
#  'omega-6脂肪酸': {'化学物', '生物学'},
#  'p': {'文字', '英国'},
#  'q': {'文字', '英国'},
#  'r': {'文字', '英国'},
#  's': {'文字', '英国'},
#  't': {'文字', '英国'},
#  'twitter': {'信息载体', '因特网', '文书', '有', '电脑'},
#  'u': {'文字', '英国'},
#  'v': {'基数', '文字', '英国'},
#  'vii': {'基数'},
#  'viii': {'基数'},
#  'w': {'文字', '英国'},
#  'x': {'文字', '英国'},
#  'xi': {'基数'},
#  'xii': {'基数'},
#  'xiii': {'基数'},
#  'xiv': {'基数'},
#  'xix': {'基数'},
#  'xvi': {'基数'},
#  'xvii': {'基数'},
#  'xviii': {'基数'},
#  'xx': {'基数'},
#  'x综合征': {'动物', '循环', '心', '疾病', '脏', '部件'},
#  'y': {'文字', '英国'},
#  'z': {'文字', '英国'},
#  '{': {'标点'},
#  '|': {'标点'},
#  '}': {'标点'},
#  '~': {'符号', '语文'},
#  '丂': {'中国', '文字'},
#  '丄': {'中国', '文字'},
#  '丅': {'中国', '文字'},
#  '丏': {'中国', '文字'},
#  '丒': {'中国', '文字'},
#  '丗': {'中国', '文字'},
#  '丟': {'中国', '文字'},
#  '丠': {'中国', '文字'},
#  '両': {'中国', '文字'},
#  '丣': {'中国', '文字'},
#  '並': {'中国', '文字'},
#  '丩': {'中国', '文字'},
#  '丮': {'中国', '文字'},
#  '丯': {'中国', '文字'},
#  '丱': {'中国', '文字'},
#  '丳': {'中国', '文字'},
#  '丵': {'中国', '文字'},
#  '丷': {'中国', '文字'},
#  '丼': {'中国', '文字'},
#  '乀': {'中国', '文字'},
#  '乁': {'中国', '文字'},
#  '乂': {'中国', '文字'},
#  '乄': {'中国', '文字'},
#  '乆': {'中国', '文字'},
#  '乊': {'中国', '文字'},
#  '乑': {'中国', '文字'},
#  '乕': {'中国', '文字'},
#  '乗': {'中国', '文字'},
#  '乚': {'中国', '文字'},
#  '乛': {'中国', '文字'},
#  '乢': {'中国', '文字'},
#  '乣': {'中国', '文字'},
#  '乧': {'中国', '文字'},
#  '乨': {'中国', '文字'},
#  '乪': {'中国', '文字'},
#  '乫': {'中国', '文字'},
#  '乮': {'中国', '文字'},
#  '乯': {'中国', '文字'},
#  '乲': {'中国', '文字'},
#  '乴': {'中国', '文字'},
#  '乵': {'中国', '文字'},
#  '乸': {'中国', '文字'},
#  '乹': {'中国', '文字'},
#  '乼': {'中国', '文字'},
#  '乿': {'中国', '文字'},
#  '亀': {'中国', '文字'},
#  '亁': {'中国', '文字'},
#  '亂': {'中国', '文字'},
#  '亃': {'中国', '文字'},
#  '亄': {'中国', '文字'},
#  '亅': {'中国', '文字'},
#  '亇': {'中国', '文字'},
#  '亊': {'中国', '文字'},
#  '亐': {'中国', '文字'},
#  '亖': {'中国', '文字'},
#  '亗': {'中国', '文字'},
#  '亙': {'中国', '文字'},
#  '亜': {'中国', '文字'},
#  '亝': {'中国', '文字'},
#  '亞': {'中国', '文字'},
#  '亣': {'中国', '文字'},
#  '亪': {'中国', '文字'},
#  '亯': {'中国', '文字'},
#  '亰': {'中国', '文字'},
#  '亱': {'中国', '文字'},
#  '亴': {'中国', '文字'},
#  '亶': {'中国', '文字'},
#  '亷': {'中国', '文字'},
#  '亸': {'姿势值', '悬挂'},
#  '亹': {'中国', '文字'},
#  '亼': {'中国', '文字'},
#  '亾': {'中国', '文字'},
#  '仈': {'中国', '文字'},
#  '仌': {'中国', '文字'},
#  '仏': {'中国', '文字'},
#  '仐': {'中国', '文字'},
#  '仚': {'中国', '文字'},
#  '仛': {'中国', '文字'},
#  '仜': {'中国', '文字'},
#  '仠': {'中国', '文字'},
#  '仢': {'中国', '文字'},
#  '仦': {'中国', '文字'},
#  '仧': {'中国', '文字'},
#  '仩': {'中国', '文字'},
#  '仭': {'中国', '文字'},
#  '仮': {'中国', '文字'},
#  '仯': {'中国', '文字'},
#  '仱': {'中国', '文字'},
#  '仴': {'中国', '文字'},
#  '仸': {'中国', '文字'},
#  '仹': {'中国', '文字'},
#  '仺': {'中国', '文字'},
#  '仼': {'中国', '文字'},
#  '仾': {'中国', '文字'},
#  '伀': {'中国', '文字'},
#  '伂': {'中国', '文字'},
#  '伃': {'中国', '文字'},
#  '伄': {'中国', '文字'},
#  '伅': {'中国', '文字'},
#  '伆': {'中国', '文字'},
#  '伇': {'中国', '文字'},
#  '伈': {'中国', '文字'},
#  '伋': {'中国', '文字'},
#  '伌': {'中国', '文字'},
#  '伒': {'中国', '文字'},
#  '伓': {'中国', '文字'},
#  '伔': {'中国', '文字'},
#  '伕': {'人', '从事', '手', '部件'},
#  '伕役': {'人', '从事', '手', '部件'},
#  '伖': {'中国', '文字'},
#  '伜': {'中国', '文字'},
#  '伝': {'中国', '文字'},
#  '伡': {'中国', '文字'},
#  '伣': {'中国', '文字'},
#  '伨': {'中国', '文字'},
#  '伩': {'中国', '文字'},
#  '伬': {'中国', '文字'},
#  '伭': {'中国', '文字'},
#  '伮': {'中国', '文字'},
#  '伱': {'中国', '文字'},
#  '伳': {'中国', '文字'},
#  '伵': {'中国', '文字'},
#  '伷': {'中国', '文字'},
#  '伹': {'中国', '文字'},
#  '伻': {'中国', '文字'},
#  '伾': {'中国', '文字'},
#  '伿': {'中国', '文字'},
#  '佀': {'中国', '文字'},
#  '佁': {'中国', '文字'},
#  '佂': {'中国', '文字'},
#  '佄': {'中国', '文字'},
#  '佅': {'中国', '文字'},
#  '佇': {'中国', '文字'},
#  '佈': {'中国', '文字'},
#  '佉': {'中国', '文字'},
#  '佊': {'中国', '文字'},
#  '佋': {'中国', '文字'},
#  '佌': {'中国', '文字'},
#  '佒': {'中国', '文字'},
#  '佔': {'中国', '文字'},
#  '佖': {'中国', '文字'},
#  '佡': {'中国', '文字'},
#  '佢': {'中国', '文字'},
#  '佦': {'中国', '文字'},
#  '佨': {'中国', '文字'},
#  '佪': {'中国', '文字'},
#  '佫': {'中国', '文字'},
#  '佭': {'中国', '文字'},
#  '佮': {'中国', '文字'},
#  '佱': {'中国', '文字'},
#  '佲': {'中国', '文字'},
#  '併': {'中国', '文字'},
#  '佷': {'中国', '文字'},
#  '佸': {'中国', '文字'},
#  '佹': {'中国', '文字'},
#  '佺': {'中国', '文字'},
#  '佽': {'中国', '文字'},
#  '侀': {'中国', '文字'},
#  '侁': {'中国', '文字'},
#  '侂': {'中国', '文字'},
#  '侅': {'中国', '文字'},
#  '來': {'中国', '文字'},
#  '侇': {'中国', '文字'},
#  '侊': {'中国', '文字'},
#  '侌': {'中国', '文字'},
#  '侎': {'中国', '文字'},
#  '侐': {'中国', '文字'},
#  '侒': {'中国', '文字'},
#  '侓': {'中国', '文字'},
#  '侕': {'中国', '文字'},
#  '侖': {'中国', '文字'},
#  '侘': {'中国', '文字'},
#  '侙': {'中国', '文字'},
#  '侚': {'中国', '文字'},
#  '侜': {'中国', '文字'},
#  '侞': {'中国', '文字'},
#  '侟': {'中国', '文字'},
#  '価': {'中国', '文字'},
#  '侢': {'中国', '文字'},
#  '侤': {'中国', '文字'},
#  '侫': {'中国', '文字'},
#  '侭': {'中国', '文字'},
#  '侰': {'中国', '文字'},
#  '侱': {'中国', '文字'},
#  '侲': {'中国', '文字'},
#  '侳': {'中国', '文字'},
#  '侴': {'中国', '文字'},
#  '侶': {'中国', '文字'},
#  '侸': {'中国', '文字'},
#  '侹': {'直'},
#  '侺': {'中国', '文字'},
#  '侻': {'幸福'},
#  '侼': {'中国', '文字'},
#  '侽': {'中国', '文字'},
#  '侾': {'中国', '文字'},
#  '俀': {'中国', '文字'},
#  '俁': {'中国', '文字'},
#  '係': {'中国', '文字'},
#  '俆': {'中国', '文字'},
#  '俇': {'中国', '文字'},
#  '俈': {'中国', '文字'},
#  '俉': {'中国', '文字'},
#  '俋': {'中国', '文字'},
#  '俌': {'中国', '文字'},
#  '俍': {'中国', '文字'},
#  '俒': {'中国', '文字'},
#  '俓': {'中国', '文字'},
#  '俔': {'中国', '文字'},
#  '俕': {'中国', '文字'},
#  '俖': {'中国', '文字'},
#  '俙': {'中国', '文字'},
#  '俛': {'中国', '文字'},
#  '俠': {'中国', '文字'},
#  '俢': {'中国', '文字'},
#  '俤': {'人', '同辈', '家庭', '男', '直系'},
#  '俥': {'中国', '文字'},
#  '俧': {'中国', '文字'},
#  '俫': {'中国', '文字'},
#  '俬': {'中国', '文字'},
#  '俰': {'中国', '文字'},
#  '俲': {'中国', '文字'},
#  '俴': {'中国', '文字'},
#  '俵': {'中国', '文字'},
#  '俶傥': {'落落大方'},
#  '俷': {'中国', '文字'},
#  '俹': {'中国', '文字'},
#  '俻': {'中国', '文字'},
#  '俼': {'中国', '文字'},
#  '俽': {'中国', '文字'},
#  '俿': {'中国', '文字'},
#  '倀': {'中国', '文字'},
#  '倁': {'中国', '文字'},
#  '倂': {'中国', '文字'},
#  '倃': {'中国', '文字'},
#  '倄': {'中国', '文字'},
#  '倅': {'中国', '文字'},
#  '倆': {'中国', '文字'},
#  '倇': {'中国', '文字'},
#  '倈': {'中国', '文字'},
#  '倉': {'中国', '文字'},
#  '倊': {'中国', '文字'},
#  '個': {'中国', '文字'},
#  '倎': {'中国', '文字'},
#  '倐': {'中国', '文字'},
#  '們': {'中国', '文字'},
#  '倓': {'中国', '文字'},
#  '倕': {'中国', '文字'},
#  '倗': {'中国', '文字'},
#  '倛': {'中国', '文字'},
#  '倝': {'中国', '文字'},
#  '倞': {'中国', '文字'},
#  '倠': {'中国', '文字'},
#  '倢': {'中国', '文字'},
#  '倢伃': {'人', '女', '皇'},
#  '倣': {'中国', '文字'},
#  '値': {'中国', '文字'},
#  '倧': {'中国', '文字'},
#  '倫': {'中国', '文字'},
#  '倯': {'中国', '文字'},
#  '倰': {'中国', '文字'},
#  '倱': {'中国', '文字'},
#  '倲': {'中国', '文字'},
#  '倳': {'中国', '文字'},
#  '倴城': {'专', '中国', '地方', '市'},
#  '倵': {'中国', '文字'},
#  '倶': {'中国', '文字'},
#  '倷': {'中国', '文字'},
#  '倸': {'中国', '文字'},
#  '倹': {'中国', '文字'},
#  '倻': {'中国', '文字'},
#  '倽': {'中国', '文字'},
#  '倿': {'中国', '文字'},
#  '偀': {'中国', '文字'},
#  '偁': {'中国', '文字'},
#  '偂': {'中国', '文字'},
#  '偄': {'中国', '文字'},
#  '偅': {'中国', '文字'},
#  '偆': {'中国', '文字'},
#  '偉': {'中国', '文字'},
#  '偊': {'中国', '文字'},
#  '偋': {'中国', '文字'},
#  '偍': {'中国', '文字'},
#  '偐': {'中国', '文字'},
#  '偑': {'中国', '文字'},
#  '偒': {'中国', '文字'},
#  '偓': {'中国', '文字'},
#  '偔': {'中国', '文字'},
#  '偖': {'中国', '文字'},
#  '偗': {'中国', '文字'},
#  '偘': {'中国', '文字'},
#  '偙': {'中国', '文字'},
#  '偛': {'中国', '文字'},
#  '偝': {'中国', '文字'},
#  '偞': {'中国', '文字'},
#  '偟': {'中国', '文字'},
#  '偠': {'中国', '文字'},
#  '偡': {'中国', '文字'},
#  '偢': {'中国', '文字'},
#  '偣': {'中国', '文字'},
#  '偤': {'中国', '文字'},
#  '偦': {'中国', '文字'},
#  '偧': {'中国', '文字'},
#  '偨': {'中国', '文字'},
#  '偩': {'中国', '文字'},
#  '偪': {'中国', '文字'},
#  '偫': {'中国', '文字'},
#  '偭': {'中国', '文字'},
#  '偮': {'中国', '文字'},
#  '偯': {'中国', '文字'},
#  '偰': {'中国', '文字'},
#  '偱': {'中国', '文字'},
#  '偲': {'中国', '文字'},
#  '偳': {'中国', '文字'},
#  '偵': {'中国', '文字'},
#  '偸': {'中国', '文字'},
#  '偹': {'中国', '文字'},
#  '偺': {'中国', '文字'},
#  '偼': {'中国', '文字'},
#  '偽': {'中国', '文字'},
#  '傁': {'中国', '文字'},
#  '傂': {'中国', '文字'},
#  '傃': {'中国', '文字'},
#  '傄': {'中国', '文字'},
#  '傆': {'中国', '文字'},
#  '傇': {'中国', '文字'},
#  '傉': {'中国', '文字'},
#  '傊': {'中国', '文字'},
#  '傋': {'中国', '文字'},
#  '傌': {'中国', '文字'},
#  '傎': {'中国', '文字'},
#  '傏': {'中国', '文字'},
#  '傐': {'中国', '文字'},
#  '傑': {'中国', '文字'},
#  '傒': {'中国', '文字'},
#  '傒倖': {'烦恼'},
#  '傓': {'中国', '文字'},
#  '傔': {'中国', '文字'},
#  '傕': {'中国', '文字'},
#  '傖': {'中国', '文字'},
#  '傗': {'中国', '文字'},
#  '傘': {'中国', '文字'},
#  '備': {'中国', '文字'},
#  '傚': {'中国', '文字'},
#  '傛': {'中国', '文字'},
#  '傜': {'中国', '文字'},
#  '傝': {'中国', '文字'},
#  '傞': {'中国', '文字'},
#  '傟': {'中国', '文字'},
#  '傠': {'中国', '文字'},
#  '傡': {'中国', '文字'},
#  '傢伙': {'人', '成年', '男'},
#  '傤': {'中国', '文字'},
#  '傦': {'中国', '文字'},
#  '傪': {'中国', '文字'},
#  '傫': {'中国', '文字'},
#  '傭': {'中国', '文字'},
#  '傮': {'中国', '文字'},
#  '傯': {'中国', '文字'},
#  '傰': {'中国', '文字'},
#  '傱': {'中国', '文字'},
#  '傳': {'中国', '文字'},
#  '傴': {'中国', '文字'},
#  '債': {'中国', '文字'},
#  '傶': {'中国', '文字'},
#  '傷': {'中国', '文字'},
#  '傸': {'中国', '文字'},
#  '傹': {'中国', '文字'},
#  '傼': {'中国', '文字'},
#  '傽': {'中国', '文字'},
#  '傾': {'中国', '文字'},
#  '傿': {'中国', '文字'},
#  '僀': {'中国', '文字'},
#  '僁': {'中国', '文字'},
#  '僂': {'中国', '文字'},
#  '僃': {'中国', '文字'},
#  '僄': {'捷'},
#  '僅': {'中国', '文字'},
#  '僆': {'中国', '文字'},
#  '僇': {'中国', '文字'},
#  '僈': {'中国', '文字'},
#  '僉': {'中国', '文字'},
#  '僊': {'中国', '文字'},
#  '僋': {'中国', '文字'},
#  '僌': {'中国', '文字'},
#  '働': {'中国', '文字'},
#  '僎': {'中国', '文字'},
#  '僐': {'中国', '文字'},
#  ...}

# %% [markdown]
# <b> If you would like to see the sememe lists for different senses of particular word in HowNet,  just need to set the param "merged" to False.</b>

# %%
hownet_dict.get_sememes_by_word("苹果",structured=False,lang="ch",merge=False)
# Out:
# [{'sememes': {'携带', '样式值', '特定牌子', '电脑', '能'}, 'word': '苹果'},
#  {'sememes': {'水果'}, 'word': '苹果'},
#  {'sememes': {'交流', '携带', '样式值', '特定牌子', '用具', '能'}, 'word': '苹果'},
#  {'sememes': {'树', '水果', '生殖'}, 'word': '苹果'},
#  {'sememes': {'树', '水果', '生殖'}, 'word': '苹果'},
#  {'sememes': {'树', '水果', '生殖'}, 'word': '苹果'}]

# %%
hownet_dict.get_sememes_by_word("apple",structured=False,lang="en",merge=False)
# Out:
# [{'sememes': {'$', 'PatternValue', 'SpeBrand', 'able', 'bring', 'computer'},
#   'word': 'apple'},
#  {'sememes': {'fruit'}, 'word': 'apple'},
#  {'sememes': {'$',
#    'PatternValue',
#    'SpeBrand',
#    'able',
#    'bring',
#    'communicate',
#    'tool'},
#   'word': 'apple'},
#  {'sememes': {'fruit', 'reproduce', 'tree'}, 'word': 'apple'},
#  {'sememes': {'$',
#    'PatternValue',
#    'SpeBrand',
#    'able',
#    'bring',
#    'communicate',
#    'tool'},
#   'word': 'apple'},
#  {'sememes': {'fruit', 'reproduce', 'tree'}, 'word': 'apple'},
#  {'sememes': {'fruit'}, 'word': 'apple'},
#  {'sememes': {'fruit'}, 'word': 'apple'}]

# %% [markdown]
# ## Get Structured Sememe Trees for certain words in HowNet

# %%
hownet_dict.get_sememes_by_word("苹果",structured=True)[0]["tree"]
# Out:
# {'children': [{'children': [{'children': [{'children': [{'name': '$',
#          'role': 'patient'}],
#        'name': 'bring|携带',
#        'role': 'scope'}],
#      'name': 'able|能',
#      'role': 'CoEvent'}],
#    'name': 'PatternValue|样式值',
#    'role': 'modifier'},
#   {'name': 'SpeBrand|特定牌子', 'role': 'patient'}],
#  'name': 'computer|电脑',
#  'role': 'None'}

# %% [markdown]
# <b> Two ways to see the corresponding annotation data </b>

# %%
hownet_dict.get_sememes_by_word("苹果",structured=True)[0]["word"]
# Out:
# {'Def': '{computer|电脑:modifier={PatternValue|样式值:CoEvent={able|能:scope={bring|携带:patient={$}}}}{SpeBrand|特定牌子}}',
#  'No': '127151',
#  'ch_grammar': 'noun',
#  'ch_word': '苹果',
#  'en_grammar': 'noun',
#  'en_word': 'apple',
#  'syn': [{'id': '004024', 'text': 'IBM'},
#   {'id': '041684', 'text': '戴尔'},
#   {'id': '049006', 'text': '东芝'},
#   {'id': '106795', 'text': '联想'},
#   {'id': '156029', 'text': '索尼'},
#   {'id': '004203', 'text': 'iPad'},
#   {'id': '019457', 'text': '笔记本'},
#   {'id': '019458', 'text': '笔记本电脑'},
#   {'id': '019459', 'text': '笔记本电脑'},
#   {'id': '019460', 'text': '笔记本电脑'},
#   {'id': '019461', 'text': '笔记本电脑'},
#   {'id': '019463', 'text': '笔记簿电脑'},
#   {'id': '019464', 'text': '笔记簿电脑'},
#   {'id': '020567', 'text': '便携式电脑'},
#   {'id': '020568', 'text': '便携式计算机'},
#   {'id': '020569', 'text': '便携式计算机'},
#   {'id': '127224', 'text': '平板电脑'},
#   {'id': '127225', 'text': '平板电脑'},
#   {'id': '172264', 'text': '膝上型电脑'},
#   {'id': '172265', 'text': '膝上型电脑'}]}

# %%
hownet_dict["苹果"][0]
# Out:
# {'Def': '{computer|电脑:modifier={PatternValue|样式值:CoEvent={able|能:scope={bring|携带:patient={$}}}}{SpeBrand|特定牌子}}',
#  'No': '127151',
#  'ch_grammar': 'noun',
#  'ch_word': '苹果',
#  'en_grammar': 'noun',
#  'en_word': 'apple',
#  'syn': [{'id': '004024', 'text': 'IBM'},
#   {'id': '041684', 'text': '戴尔'},
#   {'id': '049006', 'text': '东芝'},
#   {'id': '106795', 'text': '联想'},
#   {'id': '156029', 'text': '索尼'},
#   {'id': '004203', 'text': 'iPad'},
#   {'id': '019457', 'text': '笔记本'},
#   {'id': '019458', 'text': '笔记本电脑'},
#   {'id': '019459', 'text': '笔记本电脑'},
#   {'id': '019460', 'text': '笔记本电脑'},
#   {'id': '019461', 'text': '笔记本电脑'},
#   {'id': '019463', 'text': '笔记簿电脑'},
#   {'id': '019464', 'text': '笔记簿电脑'},
#   {'id': '020567', 'text': '便携式电脑'},
#   {'id': '020568', 'text': '便携式计算机'},
#   {'id': '020569', 'text': '便携式计算机'},
#   {'id': '127224', 'text': '平板电脑'},
#   {'id': '127225', 'text': '平板电脑'},
#   {'id': '172264', 'text': '膝上型电脑'},
#   {'id': '172265', 'text': '膝上型电脑'}]}

# %% [markdown]
# ## Get the static synonyms of the certain word
# <b>The similarity metrics are based on HowNet.</b>

# %%
hownet_dict["苹果"][0]["syn"]
# Out:
# [{'id': '004024', 'text': 'IBM'},
#  {'id': '041684', 'text': '戴尔'},
#  {'id': '049006', 'text': '东芝'},
#  {'id': '106795', 'text': '联想'},
#  {'id': '156029', 'text': '索尼'},
#  {'id': '004203', 'text': 'iPad'},
#  {'id': '019457', 'text': '笔记本'},
#  {'id': '019458', 'text': '笔记本电脑'},
#  {'id': '019459', 'text': '笔记本电脑'},
#  {'id': '019460', 'text': '笔记本电脑'},
#  {'id': '019461', 'text': '笔记本电脑'},
#  {'id': '019463', 'text': '笔记簿电脑'},
#  {'id': '019464', 'text': '笔记簿电脑'},
#  {'id': '020567', 'text': '便携式电脑'},
#  {'id': '020568', 'text': '便携式计算机'},
#  {'id': '020569', 'text': '便携式计算机'},
#  {'id': '127224', 'text': '平板电脑'},
#  {'id': '127225', 'text': '平板电脑'},
#  {'id': '172264', 'text': '膝上型电脑'},
#  {'id': '172265', 'text': '膝上型电脑'}]

# %% [markdown]
# ## Get access of the word by ID

# %%
hownet_dict["004024"]
# Out:
# ['Def', 'en_grammar', 'ch_grammar', 'No', 'syn', 'ch_word', 'en_word']

# %% [markdown]
# ## Get all sememes

# %%
hownet_dict.get_all_sememes()
# Out:
# ['模仿',
#  '保护',
#  '诱人性',
#  '问候',
#  '数量关系',
#  '仅',
#  '经济',
#  '捣乱',
#  '弊',
#  '劝说',
#  '宁乱',
#  '得罪',
#  '定期',
#  '能力值',
#  '辣',
#  '漂',
#  '友善性值',
#  '泰国',
#  '信息载体',
#  '之间',
#  '特殊性',
#  '爱尔兰',
#  '灰',
#  '幅度',
#  '不当',
#  '程度值',
#  '不稳',
#  '表示坏情感',
#  '构助',
#  '上海',
#  '发射',
#  '善待',
#  '注意',
#  '仪态',
#  '男',
#  '怯',
#  '卢旺达',
#  '中非',
#  '遭受',
#  '首次',
#  '制造',
#  '毛里求斯',
#  '扎',
#  '规矩',
#  '分析',
#  '状况',
#  '非',
#  '变形状',
#  '无礼',
#  '有序',
#  '浓',
#  '拔出',
#  '茂',
#  '疼痛',
#  '未成熟',
#  '比较',
#  '坐蹲',
#  '摩洛哥',
#  '暗',
#  '废',
#  '精',
#  '乌干达',
#  '足',
#  '朝向',
#  '采集',
#  '全面',
#  '使脏',
#  '巴布亚',
#  '平均',
#  '搀扶',
#  '不公正',
#  '推荐',
#  '积极',
#  '安哥拉',
#  '赠',
#  '叙利亚',
#  '使继续',
#  '逻辑性',
#  '印度尼西亚',
#  '支撑',
#  '托住',
#  '示喜',
#  '无望',
#  '甜',
#  '长时间',
#  '不说',
#  '准确性',
#  '叮',
#  '马达加斯加',
#  '借入',
#  '变空间位置',
#  '扎伊尔',
#  '文字',
#  '无',
#  '澳门',
#  '柔',
#  '好情',
#  '低植',
#  '气',
#  '拉脱维亚',
#  '抢',
#  '事务',
#  '贱',
#  '埋入',
#  '晚期',
#  '赞比亚',
#  '立场',
#  '格林纳达',
#  '利弊',
#  '处理',
#  '排泄',
#  '有关',
#  '清晰度',
#  '超',
#  '地方',
#  '组织',
#  '不重要',
#  '臭名',
#  '暴',
#  '印度',
#  '免除',
#  '堵塞',
#  '文莱',
#  '形成',
#  '独自',
#  '房间',
#  '喜悦',
#  '穿戴',
#  '胖瘦',
#  '标点',
#  '不讲理',
#  '利用',
#  '不适',
#  '长度值',
#  '丹麦',
#  '体格',
#  '犹豫',
#  '降级',
#  '集聚',
#  '荣',
#  '激怒',
#  '装束值',
#  '继续',
#  '巴勒斯坦',
#  '素',
#  '民用',
#  '质量',
#  '角度',
#  '萨摩亚',
#  '谴责',
#  '投下',
#  '黏度',
#  '凉',
#  '支',
#  '白俄罗斯',
#  '可能',
#  '相等',
#  '不足',
#  '放纵',
#  '罗得岛',
#  '前景差',
#  '前',
#  '相像',
#  '猜测',
#  '监察',
#  '赎',
#  '渺',
#  '出现',
#  '标准',
#  '锻炼',
#  '颠倒',
#  '浅薄',
#  '适合',
#  '无序',
#  '后天',
#  '加重',
#  '特定牌子',
#  '空满',
#  '正向',
#  '贞操',
#  '身分',
#  '喊',
#  '条约',
#  '少',
#  '塞舌尔',
#  '硬',
#  '怜悯',
#  '深度',
#  '按时',
#  '爬',
#  '辜负',
#  '明暗',
#  '南洋',
#  '上移',
#  '加快',
#  '气味',
#  '北朝鲜',
#  '难听',
#  '萨尔瓦多',
#  '升级',
#  '发炎',
#  '下去',
#  '防守',
#  '房屋',
#  '东京',
#  '络',
#  '攻打',
#  '不匀称',
#  '合并',
#  '必要性',
#  '问',
#  '已经',
#  '相关性',
#  '自杀',
#  '尝试',
#  '着重',
#  '比率',
#  '研究',
#  '量度',
#  '适应性',
#  '相比关系',
#  '吐出',
#  '英国',
#  '欧洲',
#  '原因',
#  '处于',
#  '帮助',
#  '不诚实',
#  '大概',
#  '征收',
#  '景象',
#  '经典',
#  '读物',
#  '相交',
#  '示思念',
#  '示不满',
#  '混合',
#  '精装',
#  '极',
#  '味淡',
#  '足球',
#  '辱',
#  '能',
#  '空',
#  '风格',
#  '主',
#  '有利',
#  '有创意',
#  '友善',
#  '取乐',
#  '票据',
#  '特性',
#  '中美洲',
#  '年龄',
#  '粗细值',
#  '缘于',
#  '加浓',
#  '下',
#  '疏远',
#  '乞求',
#  '高尚',
#  '脏',
#  '软',
#  '跟随',
#  '当作',
#  '相关',
#  '淘',
#  '滚',
#  '倒霉',
#  '分别的',
#  '衔起',
#  '明显性',
#  '好听',
#  '薄',
#  '瞒',
#  '周围',
#  '浸入',
#  '喜欢',
#  '慷',
#  '苏里南',
#  '费用',
#  '凹',
#  '证券',
#  '控制',
#  '深浅',
#  '距离值',
#  '洞察力',
#  '弯度',
#  '巴布亚新几内亚',
#  '逃跑',
#  '和谐',
#  '体育',
#  '木',
#  '偷',
#  '建立',
#  '易变',
#  '阿富汗',
#  '温',
#  '反抗',
#  '增多',
#  '冒险',
#  '证明',
#  '已婚',
#  '先进',
#  '连接',
#  '抗议',
#  '羞愧',
#  '栽植',
#  '序数',
#  '失望',
#  '物形',
#  '凸',
#  '衰败',
#  '感受',
#  '可靠性',
#  '逆',
#  '柴可夫斯基',
#  '理智',
#  '身矮',
#  '长',
#  '被动',
#  '久暂值',
#  '胡闹',
#  '来源值',
#  '匀称性',
#  '离开',
#  '生物',
#  '无疵',
#  '不同',
#  '新加坡',
#  '贵',
#  '瘫麻',
#  '抚',
#  '肯尼亚',
#  '愚',
#  '赞成',
#  '饮品',
#  '拾起',
#  '放松',
#  '抽搐',
#  '总计',
#  '解密',
#  '整',
#  '变',
#  '科摩罗',
#  '答',
#  '忠',
#  '语言',
#  '否',
#  '出去',
#  '珍',
#  '收',
#  '先进性',
#  '好看',
#  '荒',
#  '程度',
#  '花草',
#  '建造',
#  '尼加拉瓜',
#  '深刻',
#  '衣物',
#  '问世',
#  '回移',
#  '时间特性',
#  '莽',
#  '无能',
#  '开除',
#  '秋',
#  '地力',
#  '活动',
#  '包扎',
#  '早期',
#  '偷懒',
#  '方向性他移',
#  '划定',
#  '久暂',
#  '补做',
#  '考试',
#  '点',
#  '扭转',
#  '不舍',
#  '典雅',
#  '落落大方',
#  '方位特性值',
#  '速度值',
#  '左',
#  '状态',
#  '致敬',
#  '延续',
#  '感动',
#  '频度值',
#  '严重性',
#  '诱人',
#  '性能',
#  '给',
#  '当',
#  '格鲁吉亚',
#  '谋取',
#  '促使',
#  '概数',
#  '好坏',
#  '不必要',
#  '爱惜',
#  '妒忌',
#  '单位',
#  '拿',
#  '香',
#  '波利尼西亚',
#  '稍',
#  '捷克和斯洛伐克',
#  '成熟',
#  '招惹',
#  '出版',
#  '独特',
#  '加纳',
#  '仁',
#  '消闲',
#  '搂抱',
#  '嫁',
#  '著名',
#  '无生命',
#  '隐秘',
#  '韩国',
#  '无创意',
#  '习惯性',
#  '低等',
#  '主次',
#  '外移',
#  '分钟',
#  '外包装值',
#  '指代',
#  '功过',
#  '赚',
#  '诊察',
#  '荣辱',
#  '伊朗',
#  '排泄物',
#  '慢',
#  '画',
#  '本土',
#  '荷兰',
#  '射击',
#  '冷清',
#  '削减',
#  '使之动',
#  '住下',
#  '旬',
#  '相信',
#  '发送',
#  '纯化',
#  '胆量',
#  '做梦',
#  '不正常',
#  '成熟度',
#  '布隆迪',
#  '惬',
#  '埋怨',
#  '尾',
#  '陡',
#  '跑',
#  '便',
#  '日本',
#  '拴连',
#  '嗜好',
#  '咀嚼',
#  '制冷',
#  '差遣',
#  '功率',
#  '国籍值',
#  '留给',
#  '经受',
#  '总是',
#  '失去',
#  '战胜',
#  '不一致',
#  '未婚',
#  '没志气',
#  '缓急',
#  '时间特性值',
#  '斯威士兰',
#  '洁净',
#  '从不',
#  '清醒',
#  '看',
#  '饲养',
#  '元首',
#  '使锋利',
#  '动果',
#  '通俗',
#  '越南',
#  '机密',
#  '安慰',
#  '窄',
#  '疑似',
#  '非洲',
#  '乱',
#  '不挤',
#  '特立尼达和多巴哥',
#  '擦拭',
#  '讲和',
#  '面',
#  '教养',
#  '认知',
#  '它',
#  '乐器',
#  '尖',
#  '翅',
#  '板球',
#  '杂',
#  '热情',
#  '高矮',
#  '马拉维',
#  '中东',
#  '提及',
#  '强过',
#  '不容',
#  '行动',
#  '尼日利亚',
#  '可靠',
#  '坏风气',
#  '蛮干',
#  '使存现',
#  '意大利',
#  '争斗',
#  '迟',
#  '消灭',
#  '阿曼',
#  '总',
#  '欺骗',
#  '等待',
#  '黏',
#  '代谢',
#  '合逻辑',
#  '淫',
#  '僧伽罗',
#  '交往',
#  '特别',
#  '婉',
#  '描写',
#  '引用',
#  '印刷',
#  '普通',
#  '部件',
#  '肿胀',
#  '搬动',
#  '携带',
#  '泛动',
#  '长度',
#  '归属地方',
#  '与女性相关',
#  '哥斯达黎加',
#  '供',
#  '气味值',
#  '能力',
#  '间接',
#  '使他人感知',
#  '审问',
#  '喝',
#  '小辈',
#  '安',
#  '道歉',
#  '半',
#  '傲气',
#  '抄写',
#  '吉布提',
#  '惋惜',
#  '干',
#  '修理',
#  '庸',
#  '爱斯基摩',
#  '分发',
#  '满意',
#  '最佳',
#  '归属中央',
#  '良态',
#  '翘耸',
#  '面积',
#  '右',
#  '巴林',
#  '精确',
#  '醒',
#  '赌博',
#  '示怒',
#  '秘鲁',
#  '代替',
#  '漏出',
#  '酒',
#  '保加利亚',
#  '菲律宾',
#  '篮球',
#  '兴衰',
#  '侧',
#  '表示',
#  '火',
#  '病态',
#  '无价值',
#  '垒球',
#  '祝贺',
#  '加害',
#  '谈话',
#  '免费',
#  '吓唬',
#  '东帝汶',
#  '机动性',
#  '无诚心',
#  '具体',
#  '光',
#  '共',
#  '莱索托',
#  '高',
#  '拟人',
#  '多',
#  '农',
#  '多余',
#  '独立',
#  '颤动',
#  '苏格兰',
#  '自私',
#  '管理',
#  '通俗性',
#  '经常',
#  '心',
#  '量变',
#  '临时',
#  '成形',
#  '秃',
#  '灿烂',
#  '交配',
#  '均衡',
#  '实体',
#  '勤',
#  '外来',
#  '敢于',
#  '付',
#  '回想',
#  '内容值',
#  '散',
#  '打',
#  '永久性',
#  '间断',
#  '小',
#  '可信',
#  '高度',
#  '削弱',
#  '鼓吹',
#  '背叛',
#  '手',
#  '同意',
#  '会',
#  '减慢',
#  '非常好',
#  '积极性',
#  '还',
#  '充实',
#  '哭泣',
#  '消化',
#  '歪',
#  '有可能',
#  '海地',
#  '塞浦路斯',
#  '变外观',
#  '有罪',
#  '走兽',
#  '欠',
#  '自由度',
#  '禽',
#  '壮观',
#  '享受',
#  '加蓬',
#  '聚集',
#  '强',
#  '同辈',
#  '吃饱',
#  '烹调',
#  '推',
#  '反面',
#  '保险',
#  '转动',
#  '正常',
#  '现象',
#  '招待',
#  '胚',
#  '境况值',
#  '洒下',
#  '紫',
#  '驱赶',
#  '离别',
#  '法国',
#  '重复',
#  '有毒',
#  '阿拉伯联合酋长国',
#  '心地',
#  '装载',
#  '频度',
#  '波斯',
#  '他',
#  '保持',
#  '功',
#  '植物',
#  '生物学',
#  '直',
#  '正误',
#  '精神',
#  '没羞',
#  '属于',
#  '广',
#  '勾引',
#  '有能力',
#  '使净',
#  '缺',
#  '大',
#  '香港',
#  '人工物',
#  '过去',
#  '拆卸',
#  '洁',
#  '不坚决',
#  '南美',
#  '长辈',
#  '插入',
#  '液',
#  '斯里兰卡',
#  '揭露',
#  '死',
#  '民事',
#  '复',
#  '友',
#  '刚果',
#  '心不在焉',
#  '上去',
#  '线',
#  '配偶',
#  '接受',
#  '使成长',
#  '摆动',
#  '价格',
#  '借出',
#  '态度',
#  '唱',
#  '休息',
#  '运送',
#  '物理状态',
#  '好运',
#  '形状值',
#  '境况',
#  '龊',
#  '热量',
#  '厚',
#  '国家',
#  '上次',
#  '适宜',
#  '展示',
#  '实验',
#  '沙特阿拉伯',
#  '衰变',
#  '粗',
#  '全额',
#  '古巴',
#  '缠绕',
#  '情绪',
#  '指使',
#  '偏僻',
#  '有准备',
#  '切削',
#  '乌克兰',
#  '乡',
#  '非法',
#  '身',
#  '龄大',
#  '器具',
#  '注意力',
#  '坏天',
#  '俄罗斯',
#  '合作',
#  '智利',
#  '样式值',
#  '忍耐',
#  '理睬',
#  '很',
#  '标志',
#  '吉尔吉斯斯坦',
#  '拐弯',
#  '龄小',
#  '到达',
#  '伊斯兰教',
#  '临产',
#  '思想',
#  '谋生',
#  '有形性',
#  '象牙海岸',
#  '无意',
#  '美丑',
#  '芬兰',
#  '实现',
#  '纪律性',
#  '静态',
#  '汤加',
#  '娶',
#  '加湿',
#  '评估',
#  '回避',
#  '规划',
#  '屈服',
#  '斯洛文尼亚',
#  '推理',
#  '包围',
#  '界限',
#  '上',
#  '有功劳',
#  '志气',
#  '辫编',
#  '喷出',
#  '浇灌',
#  '罗得西亚',
#  '呼出',
#  '诚心',
#  '接近',
#  '怀孕',
#  '诚实',
#  '尖声',
#  '不友善',
#  '疲乏',
#  '疏通',
#  '合作性',
#  '劫难',
#  '礼貌',
#  '放置',
#  '智慧',
#  '价值值',
#  '私心',
#  '进入',
#  '木然',
#  '货币',
#  '争吵',
#  '领会',
#  '食物',
#  '表示情感',
#  '多少',
#  '下移',
#  '不相关',
#  '国都',
#  '同步',
#  '关系',
#  '苏丹',
#  '邀请',
#  '相互',
#  '无色',
#  '赊',
#  '容积',
#  '常态',
#  '天象',
#  '正面',
#  '称作',
#  '引导',
#  '为难',
#  '音质值',
#  '有备性',
#  '阿联酋',
#  '疯痴',
#  '内',
#  '创造',
#  '难',
#  '啃咬',
#  '稳定性',
#  '厚度',
#  '变特性',
#  '不满',
#  '分离',
#  '也门',
#  '丧偶',
#  '基数',
#  '缅甸',
#  '新近',
#  '齐',
#  '快',
#  '不成形',
#  '动物',
#  '命令',
#  '嵌入',
#  '军',
#  '经过',
#  '道路',
#  '仇恨',
#  '黄',
#  '创造性',
#  '深',
#  '表情',
#  '冰',
#  '维吾尔',
#  '搭乘',
#  '与男性相关',
#  '健康',
#  '选拔',
#  '亲密',
#  '柬埔寨',
#  '晨',
#  '调查',
#  '结果',
#  '交',
#  '墨西哥',
#  '敌',
#  '澳洲',
#  '取',
#  '单',
#  '工',
#  '异',
#  '崎岖',
#  '易',
#  '追赶',
#  '场所',
#  '浑',
#  '偶尔',
#  '己',
#  '示不同意',
#  '青',
#  '臂',
#  '低声',
#  '南斯拉夫',
#  '异步',
#  '恒定',
#  '保存',
#  '花费',
#  '谦',
#  '北京',
#  '困扰',
#  '斐济',
#  '音乐',
#  '繁',
#  '嫩',
#  '约旦',
#  '坚决',
#  '达荷美',
#  '来源',
#  '强迫',
#  '召唤',
#  '遵循',
#  '埃及',
#  '表演',
#  '粗细',
#  '符号',
#  '归属值',
#  '突尼斯',
#  '商讨',
#  '微生物',
#  '自移',
#  '药物',
#  '方向',
#  '习惯值',
#  '渐进性',
#  '导致',
#  '县',
#  '加工状况',
#  '冲淡',
#  '始',
#  '外观',
#  '扣住',
#  '奥地利',
#  '优化',
#  '忧愁',
#  '占领',
#  '致哀',
#  '羡慕',
#  '仓促',
#  '方法',
#  '狭',
#  '船',
#  '身分值',
#  '冷漠',
#  '端',
#  '学问',
#  '台湾',
#  '不值',
#  '马里',
#  '味道',
#  '难易',
#  '普鲁士',
#  '存在',
#  '直接',
#  '犹太人',
#  '终生',
#  '没可能',
#  '直系',
#  '测量',
#  '自愿',
#  '问题',
#  '道理',
#  '体液',
#  '靠近',
#  '阿尔及利亚',
#  '价格值',
#  '叠',
#  '疾病',
#  '动助',
#  '举止',
#  '消极',
#  '信息元素',
#  '朝代',
#  '正经',
#  '发达',
#  '液态',
#  ...]

# %% [markdown]
# # Advanced Feature #1: Word Similarity Calculation via Sememes
# <b>The following parts are mainly implemented by Jun Yan and integrated by Chenghao Yang. Our implementation is based on the paper: </b>
#
#   >Jiangming Liu, Jinan Xu, Yujie Zhang. An Approach of Hybrid Hierarchical Structure for Word Similarity Computing by HowNet. In Proceedings of IJCNLP

# %% [markdown]
# ## Extra Initialization

# %% [markdown]
# <b> Because there are some files required to be loaded for similarity calculation. The initialization overhead will be larger than before. To begin with, you can initialize the hownet_dict object as the following code:</b>

# %%
hownet_dict_advanced = Standards.HowNetDict(use_sim=True)

# %% [markdown]
# <b>You can also postpone the initialization work of similarity calculation until use. The following code serves as an example and the return value will indicate whether the extra initialization process succeed.</b>

# %%
hownet_dict.initialize_sememe_similarity_calculation()
# Out:
# True

# %% [markdown]
# ## Get Top-K Nearest Words for the Given Word
# <b>If the given word does not exist in HowNet annotations, this function will return an empty list.</b>

# %%
query_result = hownet_dict_advanced.get_nearest_words_via_sememes("苹果",20)
example = query_result[0]
print("word_name:",example["word"])
print("id:",example["id"])
print("synset and corresonding word&id&score:")
print(example["synset"])

# %%
hownet_dict_advanced.get_nearest_words_via_sememes("苹果",20)

# %% [markdown]
# ## Calculate the Similarity for the Given Two Words
# <b>If any of the given words does not exist in HowNet annotations, this function will return 0.</b>

# %%
hownet_dict_advanced.calculate_word_similarity("苹果","梨")
